# %%
import random

from matplotlib import colors

words = {'Colors':'red orange yellow green blue indigo violet white black brown'.split(),
'Shapes':'square triangle rectangle circle ellipse rhombus trapezoid chevron pentagon hexagon septagon octagon'.split(),
'Fruits':'apple orange lemon lime pear watermelon grape grapefruit cherry banana cantaloupe mango strawberry tomato'.split(),
'Animals':'bat bear beaver cat cougar crab deer dog donkey duck eagle fish frog goat leech lion lizard monkey moose mouse otter owl panda python rabbit rat shark sheep skunk squid tiger turkey turtle weasel whale wolf wombat zebra'.split()}

# Variables predefinidas

bienvenida = "¡bienvenidos al juego!"

mensajekey = "Elige una de las siguientes categorías, usando su número"
respuestakey = "Elegiste la siguiente categoría"

mensajevalue = "Adivina una palabra de la categoría"
respuestavalue = "Elegiste la siguiente palabra"

mensaje_adivinar = "¿Era la palabra que buscábamos?"

findejuego = "El juego ha finalizado. La palabra era"

# Inicio del juego

print(bienvenida)

# Elegir una categoria

print(mensajekey)

diccionariokeys = {1: "colors", 2: "shapes", 3: "fruits", 4:"animals"}
print(diccionariokeys)

intento = input()
intento = int(intento)
print(respuestakey, intento)

# El ordenador elige una palabra de la categoria

diccionariokeys2 = {1: words["Colors"], 2: words["Shapes"], 3: words["Fruits"], 4: words["Animals"]}

word_list = ["colors", "shapes", "fruits", "animals"]


# Adivinar una palabra

print(mensajevalue)
print(diccionariokeys2[intento])

intento2 = input ()

word_secreta = random.randint(0, len(word_list)-1)

print(respuestavalue, intento2)

# Era la palabra aleatoria?

print(mensaje_adivinar)


boolfinal = word_secreta == intento2
print(boolfinal)

# Fin del juego

print(findejuego, word_secreta)
# Out:
# ¡bienvenidos al juego!
# Elige una de las siguientes categorías, usando su número
# {1: 'colors', 2: 'shapes', 3: 'fruits', 4: 'animals'}
# Elegiste la siguiente categoría 4
# Adivina una palabra de la categoría
# ['bat', 'bear', 'beaver', 'cat', 'cougar', 'crab', 'deer', 'dog', 'donkey', 'duck', 'eagle', 'fish', 'frog', 'goat', 'leech', 'lion', 'lizard', 'monkey', 'moose', 'mouse', 'otter', 'owl', 'panda', 'python', 'rabbit', 'rat', 'shark', 'sheep', 'skunk', 'squid', 'tiger', 'turkey', 'turtle', 'weasel', 'whale', 'wolf', 'wombat', 'zebra']
# Elegiste la siguiente palabra rat
# ¿Era la palabra que buscábamos?
# False
# El juego ha finalizado. La palabra era 0

# %%
import random

from matplotlib import colors

words = {'Colors':'red orange yellow green blue indigo violet white black brown'.split(),
'Shapes':'square triangle rectangle circle ellipse rhombus trapezoid chevron pentagon hexagon septagon octagon'.split(),
'Fruits':'apple orange lemon lime pear watermelon grape grapefruit cherry banana cantaloupe mango strawberry tomato'.split(),
'Animals':'bat bear beaver cat cougar crab deer dog donkey duck eagle fish frog goat leech lion lizard monkey moose mouse otter owl panda python rabbit rat shark sheep skunk squid tiger turkey turtle weasel whale wolf wombat zebra'.split()}

# Variables predefinidas

bienvenida = "¡bienvenidos al juego!"

mensajekey = "Elige una de las siguientes categorías, usando su número"
respuestakey = "Elegiste la siguiente categoría"

mensajevalue = "Adivina una palabra de la categoría"
respuestavalue = "Elegiste la siguiente palabra"

mensaje_adivinar = "¿Era la palabra que buscábamos?"

findejuego = "El juego ha finalizado. La palabra era"

# Inicio del juego

print(bienvenida)

# Elegir una categoria

print(mensajekey)

diccionariokeys = {1: "colors", 2: "shapes", 3: "fruits", 4:"animals"}
print(diccionariokeys)

intento = input()
intento = int(intento)
print(respuestakey, intento)

# El ordenador elige una palabra de la categoria

diccionariokeys2 = {1: words["Colors"], 2: words["Shapes"], 3: words["Fruits"], 4: words["Animals"]}

word_list = ["colors", "shapes", "fruits", "animals"]


# Adivinar una palabra

print(mensajevalue)
print(diccionariokeys2[intento])

intento2 = input ()

word_secreta = random.randint(0, len(diccionariokeys2[intento])-1)

print(respuestavalue, intento2)

# Era la palabra aleatoria?

print(mensaje_adivinar)


boolfinal = diccionariokeys2[intento].index(intento2) == intento2
print(boolfinal)

# Fin del juego

print(findejuego, diccionariokeys2[intento][word_secreta])
# Out:
# ¡bienvenidos al juego!
# Elige una de las siguientes categorías, usando su número
# {1: 'colors', 2: 'shapes', 3: 'fruits', 4: 'animals'}
# Elegiste la siguiente categoría 3
# Adivina una palabra de la categoría
# ['apple', 'orange', 'lemon', 'lime', 'pear', 'watermelon', 'grape', 'grapefruit', 'cherry', 'banana', 'cantaloupe', 'mango', 'strawberry', 'tomato']
# Elegiste la siguiente palabra banana
# ¿Era la palabra que buscábamos?
# False
# El juego ha finalizado. La palabra era grapefruit
